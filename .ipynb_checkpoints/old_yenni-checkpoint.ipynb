# %% [markdown]
# ## Discrete-time competitive Beverton-Holt model

# %% [markdown]
# \begin{align}
# N_{1,t+1}=\dfrac{r_1N_{1,t}}{1+a_{11}N_{1,t}+a_{12}N_{2,t}} \\
# N_{2,t+1}=\dfrac{r_2N_{2,t}}{1+a_{22}N_{2,t}+a_{21}N_{1,t}}
# \tag{1}
# \end{align}

# %% [markdown]
# ## Packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from SALib.sample.morris import sample as ee_sample
from tqdm import tqdm

# %% [markdown]
# ## Initialization

# %%
# Variables for the time series
tmax = 100
time = np.linspace(1,tmax,tmax)
y1 = np.zeros(tmax)
#y1_t = np.zeros(tmax)
y2 = np.zeros(tmax)
#y2_t = np.zeros(tmax)
y1[0], y2[0] = 0.4, 0.6 # initial conditions
cov=np.zeros(0)

# Variables for the per capita growth rate
ymax = 100
y_increasing1 = np.linspace(1,ymax,ymax)
y_increasing2 = np.linspace(1,ymax,ymax)
per_capita1 = np.zeros(ymax)
per_capita2 = np.zeros(ymax)
y_posterior1 = np.zeros(ymax)
y_posterior2 = np.zeros(ymax)

# %% [markdown]
# ## Test for only one set of parameters

# %%
r1=15
r2=11
a11=0.7
a12=0.1
a21=0.1
a22=0.1
## Strength of stabilization
S1=r2/(1+(a12/a22)*(r2-1))
S2=r1/(1+(a21/a11)*(r1-1))                     
## Discrete-time competitive Beverton-Holt model
for i in range(tmax-1):
#    y1_t[i+1]=y1[i] # y1 in the previous step, y1[t-1]
#    y2_t[i+1]=y2[i] # y2 in the previous step, y2[t-1]
    y1[i+1] = r1 * y1[i] / ( 1 + a11 * y1[i] + a12 * y2[i] )
    y2[i+1] = r2 * y2[i] / ( 1 + a22 * y2[i] + a21 * y1[i] )

# Dummy plot
fig, ax = plt.subplots(figsize=(0.1, 0.1))
ax.plot(time, y1, alpha=0.5,linestyle="--", linewidth=10, markersize=12, color="r")
plt.rcParams.update({'font.size': 30})

fig, (ax1,ax2) = plt.subplots(2,figsize=(14, 10))
ax1.plot(time, y1, alpha=0.5,linestyle="--", linewidth=10, markersize=12, color="r", label='S1='+str(S1))
ax1.set(ylabel='$N_{1,t}$')
ax2.plot(time, y2, alpha=0.5,linestyle="--", linewidth=10, markersize=12, color="b", label='S2='+str(S2))
ax2.set(xlabel='Time (days)', ylabel='$N_{2,t}$')
plt.rcParams.update({'font.size': 30})
ax1.set_title('r1='+str(r1)+',r2='+str(r2)+',a11='+str(a11)+',a12='+str(a12)+',a21='+str(a21)+',a22='+str(a22), fontsize=25)
plt.tight_layout()
#plt.savefig('img/time_series1_r1_'+str(r1)+'_r2_'+str(r2)+'_a11_'+str(a11)+'_a12_'+str(a12)+'_a21_'+str(a21)+'_a22_'+str(a22)+'.png', format='png', dpi=50)
plt.show()

# %% [markdown]
# ## Covariance: strength of stabilization and final population

# %%
for r1 in range(15,21,5):
    for r2 in range(11,21,5):
        for a11 in np.arange(0.7,3.1,0.5):
            for a12 in np.arange(0.1,1.1,0.5):
                for a21 in np.arange(0.1,1.1,0.5):
                    for a22 in np.arange(0.1,1.1,0.5):
                        ## Strength of stabilization
                        S1=r2/(1+(a12/a22)*(r2-1))
                        S2=r1/(1+(a21/a11)*(r1-1))                     
                        ## Discrete-time competitive Beverton-Holt model
                        for i in range(tmax-1):
                            per_capita1[i] = r1 / ( 1 + a11 * y1[i] + a12 * y_increasing2[i] )
                            per_capita2[i] = r2 / ( 1 + a22 * y2[i] + a21 * y_increasing1[i] )
                            y1[i+1] = y1[i] * per_capita1[i]
                            y2[i+1] = y2[i] * per_capita2[i]
                        S=np.array([S1,S2])
                        abundance=np.array([y1[-1],y2[-1]])
                        cov=np.append(cov,np.cov(abundance, S)[0][1])

# %%
print("covariance: ",cov)
#total_population=y1+y2
cov.shape
# Out:
# covariance:  [ 4.78555209e+00 -2.08111073e+00 -4.75903433e-01  9.19088505e+00
#   2.06752383e+01  2.85984022e+00 -3.81211260e-29 -6.02432302e-30
#   1.47205825e+01 -3.04852475e+00 -1.57890879e+00  4.06005116e+00
#   2.89247774e+01  4.23476341e+00 -3.87100835e-29 -1.99869476e-29
#   2.17931681e+01 -2.29145472e+00 -1.94214057e+00  2.03830175e+00
#   3.45131749e+01  5.16616298e+00 -3.78013251e-29 -2.45849936e-29
#   2.69949617e+01 -1.35769447e+00 -2.07993473e+00  9.95861606e-01
#   3.85492397e+01  5.83884046e+00 -3.65419100e-29 -2.63292902e-29
#   3.09646359e+01 -5.00661134e-01 -2.12417759e+00  3.82026836e-01
#   4.16008985e+01  6.34745025e+00 -3.52107418e-29 -2.68893478e-29
#   9.34783674e+01  5.64480734e-01 -4.75903433e-01  1.05718548e+01
#   1.27661992e+02  1.76419761e+01  3.57739042e-26  9.32872436e-28
#   1.46054174e+02  6.12845873e+00 -1.57890879e+00  4.86561687e+00
#   1.78552308e+02  2.61236954e+01  6.21798576e-26  5.31998837e-27
#   1.82012447e+02  1.14628789e+01 -1.94214057e+00  2.60693636e+00
#   2.13026392e+02  3.18693762e+01  8.59727637e-26  9.28071853e-27
#   2.08076126e+02  1.57443849e+01 -2.07993473e+00  1.43526108e+00
#   2.37924343e+02  3.60190345e+01  1.07521481e-25  1.28702149e-26
#   2.27819421e+02  1.91489847e+01 -2.12417759e+00  7.40056039e-01
#   2.56749622e+02  3.91565811e+01  1.27129054e-25  1.61373603e-26
#  -1.00496361e+01 -7.38993993e+00 -1.03350305e+00  1.95345676e+01
#   2.23251462e+01  3.13482486e+00 -4.62983675e-20 -7.44344680e-21
#   3.03648114e+00 -1.13008007e+01 -3.47371859e+00  8.52432260e+00
#   3.24374844e+01  4.82021457e+00 -4.76836222e-20 -2.50182517e-20
#   1.33389674e+01 -1.06132796e+01 -4.32382036e+00  4.14538519e+00
#   3.97408398e+01  6.03744047e+00 -4.71398995e-20 -3.11408145e-20
#   2.13665160e+01 -9.11225810e+00 -4.68116088e+00  1.86322522e+00
#   4.52628890e+01  6.95778201e+00 -4.60773648e-20 -3.37144355e-20
#   2.77431716e+01 -7.54886229e+00 -4.82871521e+00  5.03747545e-01
#   4.95844928e+01  7.67804930e+00 -4.48506422e-20 -3.47771443e-20
#   8.71713345e+01 -1.76566323e+00 -1.03350305e+00  2.24728634e+01
#   1.37840055e+02  1.93383200e+01 -4.65118202e-20 -7.44344584e-21
#   1.52526791e+02  1.81074259e+00 -3.47371859e+00  1.02383285e+01
#   2.00221732e+02  2.97352662e+01 -4.78080939e-20 -2.50182462e-20
#   2.00579355e+02  8.28582402e+00 -4.32382036e+00  5.35527169e+00
#   2.45275166e+02  3.72441718e+01 -4.72277179e-20 -3.11408047e-20
#   2.37149646e+02  1.42689950e+01 -4.68116088e+00  2.79813752e+00
#   2.79339957e+02  4.29216370e+01 -4.61451810e-20 -3.37144219e-20
#   2.65864100e+02  1.93822252e+01 -4.82871521e+00  1.26552794e+00
#   3.05999359e+02  4.73648706e+01 -4.49058573e-20 -3.47771270e-20]
# (160,)

# %% [markdown]
# ## Time series

# %%
fig, (ax1,ax2) = plt.subplots(2,figsize=(14, 10))
ax1.plot(time, y1, alpha=0.5,linestyle="--", linewidth=10, markersize=12, color="r", label='S1='+str(S1))
ax1.set(ylabel='$N_{1,t}$')
ax2.plot(time, y2, alpha=0.5,linestyle="--", linewidth=10, markersize=12, color="b", label='S2='+str(S2))
ax2.set(xlabel='Time (days)', ylabel='$N_{2,t}$')
plt.rcParams.update({'font.size': 30})
ax1.set_title('covariance='+str(np.cov(abundance, S)[0][1])+'\n'+'r1='+str(r1)+',r2='+str(r2)+',a11='+str(a11)+',a12='+str(a12)+',a21='+str(a21)+',a22='+str(a22), fontsize=25)
plt.tight_layout()
plt.savefig('img/time_series_r1_'+str(r1)+'_r2_'+str(r2)+'_a11_'+str(a11)+'_a12_'+str(a12)+'_a21_'+str(a21)+'_a22_'+str(a22)+'.png', format='png', dpi=50)
plt.show()

# %% [markdown]
# ## Finite Growth Rate and Stock Recruitment Curve

# %%
N = np.linspace(0,ymax,ymax)
fig, (ax1,ax2,ax3,ax4) = plt.subplots(4,figsize=(14, 10))
# Finite Growth Rate
ax1.plot(N, per_capita1, alpha=0.5,linestyle="dotted", linewidth=10, markersize=12, color="r")
ax1.axhline(y=1, color='grey', linestyle='-')
ax1.set(ylabel='$N_{1,t+1}/N_{1,t}$')
# Stock-Recruitment
ax2.plot(N, y_posterior1, alpha=0.5,linestyle="dotted", linewidth=10, markersize=12, color="y")
ax2.plot(N,N, color="grey") # add a straight line
ax2.set_ylim([-1, 10])
ax2.set(xlabel='$N_{1,t}$', ylabel='$N_{1,t+1}$')
# Finite Growth Rate
ax3.plot(N, per_capita2, alpha=0.5,linestyle="dotted", linewidth=10, markersize=12, color="b")
ax3.axhline(y=1, color='grey', linestyle='-')
ax3.set(ylabel='$N_{2,t+1}/N_{2,t}$')
# Stock-Recruitment
ax4.plot(N, y_posterior2, alpha=0.5,linestyle="dotted", linewidth=10, markersize=12, color="g")
ax4.plot(N,N, color="grey") # add a straight line
ax4.set_ylim([-1, 20])
ax4.set(xlabel='$N_{2,t}$', ylabel='$N_{2,t+1}$')
plt.rcParams.update({'font.size': 30})
ax1.set_title('covariance='+str(np.cov(abundance, S)[0][1])+'\n'+'r1='+str(r1)+',r2='+str(r2)+',a11='+str(a11)+',a12='+str(a12)+',a21='+str(a21)+',a22='+str(a22), fontsize=25)
plt.tight_layout(pad=0)
plt.savefig('img/finite_growth_rate_r1_'+str(r1)+'_r2_'+str(r2)+'_a11_'+str(a11)+'_a12_'+str(a12)+'_a21_'+str(a21)+'_a22_'+str(a22)+'.png', format='png', dpi=50, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Yenni's graph

# %%
fig, (ax1,ax2) = plt.subplots(2,figsize=(14, 10))
ax1.plot(N, np.log(per_capita1), alpha=0.5,linestyle="-", linewidth=10, markersize=12, color="r", label='$N_{1,t}$')
ax1.axhline(y=0, color='grey', linestyle='-')
ax1.set(ylabel='$\log(N_{1,t+1}/N_{1,t})$')
ax2.plot(N, np.log(per_capita2), alpha=0.5,linestyle="-", linewidth=10, markersize=12, color="b", label='$N_{2,t}$')
ax2.axhline(y=0, color='grey', linestyle='-')
ax2.set(xlabel='Frequency', ylabel='$\log(N_{2,t+1}/N_{2,t})$')
plt.rcParams.update({'font.size': 30})
ax1.legend()
ax2.legend()
ax1.set_title('covariance='+str(np.cov(abundance, S)[0][1])+'\n'+'r1='+str(r1)+',r2='+str(r2)+',a11='+str(a11)+',a12='+str(a12)+',a21='+str(a21)+',a22='+str(a22), fontsize=25)
plt.tight_layout()
plt.savefig('img/frequency_dependence_covariance_'+str(np.cov(abundance, S)[0][1])+'_r1_'+str(r1)+'_r2_'+str(r2)+'_a11_'+str(a11)+'_a12_'+str(a12)+'_a21_'+str(a21)+'_a22_'+str(a22)+'.png', format='png', dpi=50)
plt.show()
# Out:
# /tmp/ipykernel_9067/1488022116.py:2: RuntimeWarning: divide by zero encountered in log
#   ax1.plot(N, np.log(per_capita1), alpha=0.5,linestyle="-", linewidth=10, markersize=12, color="r", label='$N_{1,t}$')
# /tmp/ipykernel_9067/1488022116.py:5: RuntimeWarning: divide by zero encountered in log
#   ax2.plot(N, np.log(per_capita2), alpha=0.5,linestyle="-", linewidth=10, markersize=12, color="b", label='$N_{2,t}$')
