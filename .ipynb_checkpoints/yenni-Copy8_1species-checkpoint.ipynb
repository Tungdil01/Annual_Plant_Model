# %% [markdown]
# ## Discrete-time competitive Beverton-Holt model

# %% [markdown]
# \begin{align}
# N_{1,t+1}=\dfrac{r_1N_{1,t}}{1+a_{11}N_{1,t}+a_{12}N_{2,t}} \\
# N_{2,t+1}=\dfrac{r_2N_{2,t}}{1+a_{22}N_{2,t}+a_{21}N_{1,t}}
# \tag{1}
# \end{align}

# %% [markdown]
# ## Packages

# %%
import numpy as np # math expressions
import matplotlib.pyplot as plt # plot

# %%
# Dummy plot
fig, ax = plt.subplots(figsize=(0.1, 0.1))
ax.axhline(y=1, color='grey', linestyle='-')
plt.rcParams.update({'font.size': 30})

# %% [markdown]
# ## Initialization

# %%
# Variables for the per capita growth rate
tmax = 2
time = np.linspace(1,tmax,tmax)

y1 = np.zeros(tmax)
per_capita1 = np.zeros(tmax)

y1[0] = 5 # initial conditions

# %% [markdown]
# ## Parameters

# %% [markdown]
# r1=20
# r2=16
# a11=2.7
# a12=0.6
# a21=0.6
# a22=0.6

# %% [markdown]
# ## cov > 0

# %% [markdown]
# r1=20
# r2=12
# a11=1
# a12=1
# a21=0.1
# a22=1

# %% [markdown]
# ## cov < 0

# %% [markdown]
# r1=20
# r2=11
# a11=1
# a12=1
# a21=0.1
# a22=1

# %% [markdown]
# ## cov = zero

# %% [markdown]
# r1=20
# r2=11
# a11=1
# a12=1
# a21=1
# a22=1

# %%
r1=17
r2=19
a11=2.1
a12=0.3
a21=0.1
a22=0.9

# %%
## Discrete-time competitive Beverton-Holt model
i=0
stopRun=0
while stopRun==0: # stops the simulation when the dynamics converges
    per_capita1[i] = r1 / ( 1 + a11 * y1[i] )
    y1[i+1] = y1[i] * per_capita1[i]
    per_capita1=np.append(per_capita1,per_capita1[i])
    y1=np.append(y1,y1[i])
    if(np.abs(y1[i+1]-y1[i]) < 0.01):
        stopRun=1
    i+=1 # i=i+1

# %% [markdown]
# ## Relative frequency

# %%
tmax = len(y1)
time = np.linspace(1,tmax,tmax)

fig, (ax) = plt.subplots(1,figsize=(8, 6))
ax.plot(time, y1, alpha=0.5,linestyle="--", linewidth=10, markersize=12, color="r", label='$N_{1}$')
ax.set(xlabel='Time (days)', ylabel='$N_{t}$')
ax.legend()
plt.rcParams.update({'font.size': 30})
ax.set_title('r1='+str(r1)+',r2='+str(r2)+',a11='+str(a11)+',a12='+str(a12)+',a21='+str(a21)+',a22='+str(a22), fontsize=25)
plt.tight_layout()
plt.savefig('img/yenni_time_series_r1_'+str(r1)+'_r2_'+str(r2)+'_a11_'+str(a11)+'_a12_'+str(a12)+'_a21_'+str(a21)+'_a22_'+str(a22)+'.png', format='png', dpi=50)
plt.show()

# %%
tmax = len(y1)
time = np.linspace(1,tmax,tmax)

fig, (ax) = plt.subplots(1,figsize=(8, 6))
ax.plot(time, np.log(per_capita1), alpha=0.5,linestyle="--", linewidth=10, markersize=12, color="r", label='$N_{1}$')
ax.plot(time, np.log(per_capita2), alpha=0.5,linestyle="--", linewidth=10, markersize=12, color="b", label='$N_{2}$')
ax.set(xlabel='Time (days)', ylabel='log(Growth rate)')
ax.axhline(y=0, color='grey', linestyle='-')
ax.legend()
plt.rcParams.update({'font.size': 30})
ax.set_title('r1='+str(r1)+',r2='+str(r2)+',a11='+str(a11)+',a12='+str(a12)+',a21='+str(a21)+',a22='+str(a22), fontsize=25)
plt.tight_layout()
plt.savefig('img/yenni_time_series_r1_'+str(r1)+'_r2_'+str(r2)+'_a11_'+str(a11)+'_a12_'+str(a12)+'_a21_'+str(a21)+'_a22_'+str(a22)+'.png', format='png', dpi=50)
plt.show()
# Out:
# /tmp/ipykernel_10868/1769496156.py:5: RuntimeWarning: divide by zero encountered in log
#   ax.plot(time, np.log(per_capita1), alpha=0.5,linestyle="--", linewidth=10, markersize=12, color="r", label='$N_{1}$')
# /tmp/ipykernel_10868/1769496156.py:6: RuntimeWarning: divide by zero encountered in log
#   ax.plot(time, np.log(per_capita2), alpha=0.5,linestyle="--", linewidth=10, markersize=12, color="b", label='$N_{2}$')

# %%
fig, (ax) = plt.subplots(1,figsize=(8, 6))
ax.plot(y_rel1,np.log(per_capita1), alpha=0.5,linestyle="--", linewidth=10, markersize=12, color="r", label='$N_{1}$')
ax.plot(y_rel2,np.log(per_capita2), alpha=0.5,linestyle="--", linewidth=10, markersize=12, color="b", label='$N_{2}$')
ax.set(xlabel='$N_t$', ylabel='log(PGR)')
ax.axhline(y=0, color='grey', linestyle='-')
ax.legend()
plt.rcParams.update({'font.size': 30})
ax.set_title('r1='+str(r1)+',r2='+str(r2)+',a11='+str(a11)+',a12='+str(a12)+',a21='+str(a21)+',a22='+str(a22), fontsize=25)
plt.tight_layout()
#plt.savefig('img/yenni_time_series_r1_'+str(r1)+'_r2_'+str(r2)+'_a11_'+str(a11)+'_a12_'+str(a12)+'_a21_'+str(a21)+'_a22_'+str(a22)+'.png', format='png', dpi=50)
plt.show()
# Out:
# /tmp/ipykernel_10868/3561013747.py:2: RuntimeWarning: divide by zero encountered in log
#   ax.plot(y_rel1,np.log(per_capita1), alpha=0.5,linestyle="--", linewidth=10, markersize=12, color="r", label='$N_{1}$')
# /tmp/ipykernel_10868/3561013747.py:3: RuntimeWarning: divide by zero encountered in log
#   ax.plot(y_rel2,np.log(per_capita2), alpha=0.5,linestyle="--", linewidth=10, markersize=12, color="b", label='$N_{2}$')

# %%
# Same result:
growth1 = np.log(y1[1:-1])-np.log(y1[0:-2])
growth2 = np.log(y2[1:-1])-np.log(y2[0:-2])

fig, (ax) = plt.subplots(1,figsize=(8, 6))
ax.plot(y_rel1[:-2], growth1, alpha=0.5,linestyle="--", linewidth=10, markersize=12, color="r")
ax.plot(y_rel2[:-2], growth2, alpha=0.5,linestyle="--", linewidth=10, markersize=12, color="b")
ax.set(xlabel='Frequency', ylabel='log(Growth rate)')
ax.axhline(y=0, color='grey', linestyle='-')
plt.rcParams.update({'font.size': 30})
ax.set_title('r1='+str(r1)+',r2='+str(r2)+',a11='+str(a11)+',a12='+str(a12)+',a21='+str(a21)+',a22='+str(a22), fontsize=25)
plt.tight_layout()
plt.savefig('img/yenni_time_series_r1_'+str(r1)+'_r2_'+str(r2)+'_a11_'+str(a11)+'_a12_'+str(a12)+'_a21_'+str(a21)+'_a22_'+str(a22)+'.png', format='png', dpi=50)
plt.show()
# Out:
# /tmp/ipykernel_10868/1066109185.py:3: RuntimeWarning: divide by zero encountered in log
#   growth2 = np.log(y2[1:-1])-np.log(y2[0:-2])
# /tmp/ipykernel_10868/1066109185.py:3: RuntimeWarning: invalid value encountered in subtract
#   growth2 = np.log(y2[1:-1])-np.log(y2[0:-2])
