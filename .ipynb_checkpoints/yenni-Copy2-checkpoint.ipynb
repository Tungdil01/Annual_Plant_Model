# %% [markdown]
# ## Discrete-time competitive Beverton-Holt model

# %% [markdown]
# \begin{align}
# N_{1,t+1}=\dfrac{r_1N_{1,t}}{1+a_{11}N_{1,t}+a_{12}N_{2,t}} \\
# N_{2,t+1}=\dfrac{r_2N_{2,t}}{1+a_{22}N_{2,t}+a_{21}N_{1,t}}
# \tag{1}
# \end{align}

# %% [markdown]
# ## Packages

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Initialization

# %%
x0 = 100              # initial amount of individuals
M = 500               # carrying capacity
rho = 4               # initial growth rate in percent
N = 200               # number of time intervals
index_set = range(N+1)
x = np.zeros(len(index_set))

# %% [markdown]
# ## Compute solution

# %%
x[0] = x0
for n in index_set[1:]:
    x[n] = x[n-1] + (rho/100.0)*x[n-1]*(1 - x[n-1]/float(M))
#print(x)

# %%
fig, (ax) = plt.subplots(1,figsize=(14, 10))
ax.plot(index_set, x, 'r')
ax.set(xlabel='time units', ylabel='$N$')
# Out:
# [Text(0.5, 0, 'time units'), Text(0, 0.5, '$N$')]
